# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('data1.csv')

# %%
df
# Out:
#              Time  Cell_length        DNA1        DNA2     CD45RA     CD133  \
# 0         2693.00         22.0   201.78330   253.01665   0.817049 -0.147947
# 1         3736.00         35.0   191.82860   308.86908   3.801385 -0.191446
# 2         7015.00         32.0   116.11192   200.83922   3.204439 -0.161106
# 3         7099.00         29.0   176.24850   313.02246   2.237382 -0.138071
# 4         7700.00         25.0   133.33278   226.46776  -0.044047 -0.151509
# ...           ...          ...         ...         ...        ...       ...
# 265622  707951.44         41.0  2305.19120  3131.64140  10.345075 -0.095875
# 265623  708145.44         45.0  2217.37700  3198.11430   0.585101 -0.281215
# 265624  708398.44         41.0  2455.67330  3157.41630   3.698715 -0.031322
# 265625  708585.44         39.0  2395.88380  3167.32540   1.463955 -0.056550
# 265626  709122.44         41.0  2450.65330  3113.95500   1.843143  0.644794
#
#             CD19      CD22       CD11b        CD4  ...     CD117      CD49d  \
# 0      -0.033482  0.332183   -0.045922   1.858334  ...  0.265375   4.804858
# 1      -0.083274  0.372388    4.494379  -0.177158  ...  0.448901   0.995556
# 2       0.369613 -0.214952   -0.009404  -0.043904  ...  0.231194  33.025460
# 3      -0.088311 -0.220430    4.006598  -0.095335  ...  0.332596   8.879428
# 4       0.402548  2.581769    6.742060   2.906627  ... -0.031117   0.909562
# ...          ...       ...         ...        ...  ...       ...        ...
# 265622 -0.278241 -0.036303    0.317188   0.729079  ... -0.055526   2.797205
# 265623 -0.044320 -0.175828   -0.209287   5.648056  ...  0.721827   8.194910
# 265624 -0.130569 -0.154208   -0.173241  11.841664  ...  0.436060  -0.279705
# 265625 -0.244025  0.370252   -0.158964   0.394406  ... -0.239947   0.510660
# 265626 -0.034668  0.550337  119.171364   4.389215  ...  0.401405   0.189855
#
#              HLA-DR      CD64      CD41  Viability  file_number  event_number  \
# 0         12.734092 -0.026878 -0.009804   3.474168         94.0         307.0
# 1          2.558165  0.726602  4.905976   2.956692         94.0         545.0
# 2          8.574364 -0.054804 -0.052067   3.443209         94.0        1726.0
# 3          0.704930 -0.067247 -0.130211  -0.132632         94.0        1766.0
# 4          0.993077  0.381205 -0.202496   1.435458         94.0        2031.0
# ...             ...       ...       ...        ...          ...           ...
# 265622     0.620372 -0.212540 -0.139874   1.195905         98.0      102686.0
# 265623     0.236164 -0.039998 -0.129067  -0.017502         98.0      102690.0
# 265624     2.614140  0.269550 -0.213073   0.537059         98.0      102701.0
# 265625  1231.869100  1.506284  0.969914   3.307683         98.0      102706.0
# 265626    98.570404 -0.004392 -0.262749   1.577387         98.0      102720.0
#
#         label  individual
# 0         1.0         1.0
# 1         1.0         1.0
# 2         1.0         1.0
# 3         1.0         1.0
# 4         1.0         1.0
# ...       ...         ...
# 265622    NaN         2.0
# 265623    NaN         2.0
# 265624    NaN         2.0
# 265625    NaN         2.0
# 265626    NaN         2.0
#
# [265627 rows x 41 columns]

# %%
df.max()
# Out:
# Time            709122.440000
# Cell_length         65.000000
# DNA1              2745.666500
# DNA2              4396.652300
# CD45RA            2013.210300
# CD133              628.772460
# CD19               367.355300
# CD22               435.604520
# CD11b              481.570680
# CD4               1804.521100
# CD8                273.117200
# CD34               430.201300
# Flt3              3082.859600
# CD20              1061.773900
# CXCR4              744.679260
# CD235ab           1925.590200
# CD45              3478.534000
# CD123             1913.932400
# CD321             2401.089400
# CD14               373.294160
# CD33               684.539500
# CD47              1508.356900
# CD11c             1698.035600
# CD7               1387.843900
# CD15                11.054365
# CD16               520.386900
# CD44              4108.670000
# CD38              3675.246600
# CD13              2690.485800
# CD3               2131.651100
# CD61              5795.215000
# CD117              613.020750
# CD49d              432.548900
# HLA-DR            2889.379000
# CD64               229.066960
# CD41              5622.765000
# Viability           28.263973
# file_number         98.000000
# event_number    400112.000000
# label               14.000000
# individual           2.000000
# dtype: float64

# %%
df.min()
# Out:
# Time             1.000000
# Cell_length     10.000000
# DNA1            40.405746
# DNA2            23.133020
# CD45RA          -0.286683
# CD133           -0.290567
# CD19            -0.290608
# CD22            -0.286868
# CD11b           -0.291343
# CD4             -0.288916
# CD8             -0.290179
# CD34            -0.290203
# Flt3            -0.289583
# CD20            -0.290826
# CXCR4           -0.285367
# CD235ab         -0.288219
# CD45            18.906206
# CD123           -0.290179
# CD321           -0.267886
# CD14            -0.289934
# CD33            -0.290558
# CD47            -0.275576
# CD11c           -0.290427
# CD7             -0.290972
# CD15            -0.290547
# CD16            -0.289060
# CD44             0.130320
# CD38            -0.286126
# CD13            -0.288799
# CD3             -0.291369
# CD61            -0.288369
# CD117           -0.288499
# CD49d           -0.290482
# HLA-DR          -0.290032
# CD64            -0.291160
# CD41            -0.291384
# Viability       -0.290059
# file_number     94.000000
# event_number     1.000000
# label            1.000000
# individual       1.000000
# dtype: float64

# %%
import matplotlib.pyplot as plt, mpld3
plt.plot([3,1,4,1,5], 'ks-', mec='w', mew=5, ms=20)
# mpld3.show()
save_html('test.html')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       2 plt.plot([3,1,4,1,5], 'ks-', mec='w', mew=5, ms=20)
#       3 # mpld3.show()
# ----> 4 save_html('test.html')
#
# NameError: name 'save_html' is not defined

# %%
import pandas as pd
import matplotlib.pyplot as plt
import mpld3
# Create your matplotlib plot
fig, ax = plt.subplots()
ax.plot([1, 2, 3, 4, 5], [1, 4, 9, 16, 25])
mpld3.show()

# Generate mpld3 HTML
html = mpld3.fig_to_html(fig)

# Save the HTML file
with open('mpld3_plot.html', 'w') as file:
    file.write(html)
# Out:
# Note: if you're in the IPython notebook, mpld3.show() is not the best command
#       to use. Consider using mpld3.display(), or mpld3.enable_notebook().
#       See more information at http://mpld3.github.io/quickstart.html .
#
# You must interrupt the kernel to end this command
#
# Serving to http://127.0.0.1:8888/    [Ctrl-C to exit]
# 127.0.0.1 - - [29/May/2023 17:40:48] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [29/May/2023 17:40:48] "GET /d3.js HTTP/1.1" 200 -
# 127.0.0.1 - - [29/May/2023 17:40:48] "GET /mpld3.js HTTP/1.1" 200 -
# 127.0.0.1 - - [29/May/2023 17:42:31] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [29/May/2023 17:42:37] "GET / HTTP/1.1" 200 -
# stopping Server...
